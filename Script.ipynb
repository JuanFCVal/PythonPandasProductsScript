# %%
#import dependencies
import pandas as pd
from pprint import pprint
#Read Kaggle Files
df1 = pd.read_csv('C:/Users/Usuario/Desktop/Juan/Universidad/Tesis/datasets/products/FashionClothing.csv', encoding = 'ISO-8859-1')
df2 = pd.read_csv('C:/Users/Usuario/Desktop/Juan/Universidad/Tesis/datasets/products2/SummerProducts.csv', encoding = 'ISO-8859-1')

# %%
from translate import Translator
translator= Translator(from_lang="english", to_lang="spanish")
translation = translator.translate("Hello, I'm really sure that this    it's  and it's not even a real ")
print(translation)
# Out:
# Y ni siquiera está cerca.

# %%
df1.head()
# Out:
#                                          Product_URL                 Brand  \
# 0  https://www.ajio.com/netplay-checked-polo-t-sh...               netplay
# 1  https://www.ajio.com/netplay-tapered-fit-flat-...               netplay
# 2  https://www.ajio.com/the-indian-garage-co-stri...  the-indian-garage-co
# 3  https://www.ajio.com/performax-heathered-crew-...             performax
# 4  https://www.ajio.com/john-players-jeans-washed...    john-players-jeans
#
#                                 Description    Id_Product  \
# 0                      Checked Polo T-shirt  441137362002
# 1           Tapered Fit Flat-Front Trousers  441124497006
# 2  Striped Slim Fit Shirt with Patch Pocket  460453612003
# 3               Heathered Crew-Neck T-shirt  441036730003
# 4     Washed Skinny Fit Jeans with Whiskers  441128531011
#
#                                            URL_image Category_by_gender  \
# 0  https://assets.ajio.com/medias/sys_master/root...                Men
# ...

# %%
df1 = df1[['Product_URL', 'Brand', "Description", "URL_image", "Color", "Category_by_gender"]]
df1FinalVer = df1.iloc[:1500]
df1FinalVer
# Out:
#                                             Product_URL                 Brand  \
# 0     https://www.ajio.com/netplay-checked-polo-t-sh...               netplay
# 1     https://www.ajio.com/netplay-tapered-fit-flat-...               netplay
# 2     https://www.ajio.com/the-indian-garage-co-stri...  the-indian-garage-co
# 3     https://www.ajio.com/performax-heathered-crew-...             performax
# 4     https://www.ajio.com/john-players-jeans-washed...    john-players-jeans
# ...                                                 ...                   ...
# 1495  https://www.ajio.com/campus-sutra-mid-wash-jea...          campus-sutra
# 1496  https://www.ajio.com/levis-brand-print-crew-ne...                 levis
# 1497  https://www.ajio.com/adidas-shorts-with-stripe...                adidas
# 1498  https://www.ajio.com/lee-cooper-lightly-washed...            lee-cooper
# 1499  https://www.ajio.com/netplay-flat-front-chinos...               netplay
#
# ...

# %%
df1
# Out:
#                                               Product_URL  \
# 0       https://www.ajio.com/netplay-checked-polo-t-sh...
# 1       https://www.ajio.com/netplay-tapered-fit-flat-...
# 2       https://www.ajio.com/the-indian-garage-co-stri...
# 3       https://www.ajio.com/performax-heathered-crew-...
# 4       https://www.ajio.com/john-players-jeans-washed...
# ...                                                   ...
# 367167  https://www.ajio.com/indie-picks-woven-pochamp...
# 367168  https://www.ajio.com/indie-picks-woven-pochamp...
# 367169  https://www.ajio.com/griva-designer-floral-emb...
# 367170  https://www.ajio.com/global-desi-pleated-dhoti...
# 367171  https://www.ajio.com/sakura-micro-print-a-line...
#
#                        Brand                                      Description  \
# 0                    netplay                             Checked Polo T-shirt
# 1                    netplay                  Tapered Fit Flat-Front Trousers
# ...

# %%
df2.count()
# Out:
# title                           1573
# title_orig                      1573
# price                           1573
# retail_price                    1573
# currency_buyer                  1573
# units_sold                      1573
# uses_ad_boosts                  1573
# rating                          1573
# rating_count                    1573
# rating_five_count               1528
# rating_four_count               1528
# rating_three_count              1528
# rating_two_count                1528
# rating_one_count                1528
# badges_count                    1573
# badge_local_product             1573
# badge_product_quality           1573
# badge_fast_shipping             1573
# tags                            1573
# product_color                   1532
# product_variation_size_id       1559
# product_variation_inventory     1573
# shipping_option_name            1573
# shipping_option_price           1573
# shipping_is_express             1573
# ...
