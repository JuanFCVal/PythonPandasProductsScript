# %%
#import dependencies
import pandas as pd
from pprint import pprint
#Read Kaggle Files in my DataFrame  
df1 = pd.read_csv('FashionClothing.csv', encoding = 'ISO-8859-1')
df2 = pd.read_csv('SummerProducts.csv', encoding = 'ISO-8859-1')

# %%
df1.head()  #Reading File 1
# Out:
#                                          Product_URL                 Brand  \
# 0  https://www.ajio.com/netplay-checked-polo-t-sh...               netplay
# 1  https://www.ajio.com/netplay-tapered-fit-flat-...               netplay
# 2  https://www.ajio.com/the-indian-garage-co-stri...  the-indian-garage-co
# 3  https://www.ajio.com/performax-heathered-crew-...             performax
# 4  https://www.ajio.com/john-players-jeans-washed...    john-players-jeans
#
#                                 Description    Id_Product  \
# 0                      Checked Polo T-shirt  441137362002
# 1           Tapered Fit Flat-Front Trousers  441124497006
# 2  Striped Slim Fit Shirt with Patch Pocket  460453612003
# 3               Heathered Crew-Neck T-shirt  441036730003
# 4     Washed Skinny Fit Jeans with Whiskers  441128531011
#
#                                            URL_image Category_by_gender  \
# 0  https://assets.ajio.com/medias/sys_master/root...                Men
# ...

# %%
df1 = df1[['Product_URL', 'Brand', "Description", "URL_image", "Color", "Category_by_gender"]]  #Filter dataframe with relevant Columns
df1FinalVer = df1.iloc[:1500]
df1FinalVer
# Out:
#                                             Product_URL                 Brand  \
# 0     https://www.ajio.com/netplay-checked-polo-t-sh...               netplay
# 1     https://www.ajio.com/netplay-tapered-fit-flat-...               netplay
# 2     https://www.ajio.com/the-indian-garage-co-stri...  the-indian-garage-co
# 3     https://www.ajio.com/performax-heathered-crew-...             performax
# 4     https://www.ajio.com/john-players-jeans-washed...    john-players-jeans
# ...                                                 ...                   ...
# 1495  https://www.ajio.com/campus-sutra-mid-wash-jea...          campus-sutra
# 1496  https://www.ajio.com/levis-brand-print-crew-ne...                 levis
# 1497  https://www.ajio.com/adidas-shorts-with-stripe...                adidas
# 1498  https://www.ajio.com/lee-cooper-lightly-washed...            lee-cooper
# 1499  https://www.ajio.com/netplay-flat-front-chinos...               netplay
#
# ...

# %%
df2 = df2[['title', 'price', "retail_price", "units_sold", "rating", "rating_count", 'tags', "product_color", "product_picture"]]  #Filter dataframe with relevant Columns
df2FinalVer = df2.iloc[:1500]                                                                   #Filter DataFrame Just to take 1500 Rows.
df2FinalVer
# Out:
#                                                   title  price  retail_price  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1     SSHOUSE Summer Casual Sleeveless SoirÃ©e Party...   8.00            22
# 2     2020 Nouvelle ArrivÃ©e Femmes Printemps et Ãt...   8.00            43
# 3     Hot Summer Cool T-shirt pour les femmes Mode T...   8.00             8
# 4     Femmes Shorts d'Ã©tÃ© Ã  lacets taille Ã©lasti...   2.72             3
# ...                                                 ...    ...           ...
# 1495  Femmes d'Ã©tÃ© dÃ©contractÃ© couleur unie col ...   6.00            11
# 1496  Mode fÃ©minine grande taille Tops manches cour...   7.00             6
# 1497  Mode Ocean Wave Bague Argent et Or Rose Bague ...   3.66             4
# 1498  Plus Size S-5XL Women Fashion Tube Top Dress O...   7.00            50
# 1499  Femmes Ã©tÃ© mode lacets pantalon court dÃ©con...   6.00            76
#
#       units_sold  rating  rating_count  \
# ...

# %%
for col in df2FinalVer.columns:
    df1FinalVer[col] = df2FinalVer[col]
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_17464\3288303009.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1FinalVer[col] = df2FinalVer[col]
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_17464\3288303009.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1FinalVer[col] = df2FinalVer[col]
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_17464\3288303009.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df1FinalVer
# Out:
#                                             Product_URL                 Brand  \
# 0     https://www.ajio.com/netplay-checked-polo-t-sh...               netplay
# 1     https://www.ajio.com/netplay-tapered-fit-flat-...               netplay
# 2     https://www.ajio.com/the-indian-garage-co-stri...  the-indian-garage-co
# 3     https://www.ajio.com/performax-heathered-crew-...             performax
# 4     https://www.ajio.com/john-players-jeans-washed...    john-players-jeans
# ...                                                 ...                   ...
# 1495  https://www.ajio.com/campus-sutra-mid-wash-jea...          campus-sutra
# 1496  https://www.ajio.com/levis-brand-print-crew-ne...                 levis
# 1497  https://www.ajio.com/adidas-shorts-with-stripe...                adidas
# 1498  https://www.ajio.com/lee-cooper-lightly-washed...            lee-cooper
# 1499  https://www.ajio.com/netplay-flat-front-chinos...               netplay
#
# ...

# %%
import random
idArray = []
for x in range(0, 1500):
    idArray.append(random.randint(1, 15))
len(idArray)
# Out:
# 1500

# %%
counterDictionary = {}
for x in idArray:
    print(x)
# Out:
# 6
# 10
# 6
# 9
# 5
# 14
# 2
# 3
# 8
# 4
# 1
# 8
# 1
# 9
# 12
# 14
# 13
# 10
# 13
# 15
# 7
# 4
# 4
# 6
# 4
# 14
# 5
# 7
# 14
# 8
# 8
# 11
# 2
# 10
# 9
# 15
# 12
# 12
# 10
# 11
# 11
# 12
# 7
# 8
# 12
# 11
# 13
# 5
# 2
# 2
# 4
# 9
# 7
# 1
# 6
# 6
# 10
# 2
# 4
# 4
# 15
# 6
# 6
# 6
# 11
# 2
# 6
# 6
# 6
# 14
# 12
# 15
# 6
# 1
# 4
# 5
# 11
# 14
# 1
# 4
# 4
# 13
# 14
# 11
# 12
# 15
# 2
# 4
# 6
# 2
# 9
# 15
# 3
# 5
# 6
# 13
# 6
# 12
# 12
# 12
# 5
# 5
# 10
# 1
# 11
# 3
# 11
# 12
# 13
# 6
# 4
# 12
# 7
# 15
# 3
# 8
# 7
# 10
# 14
# 10
# 3
# 11
# 6
# 15
# 3
# 4
# 9
# 5
# 13
# 2
# 13
# 15
# 7
# 11
# 15
# 9
# 13
# 1
# 13
# 7
# 1
# 6
# 3
# 8
# 5
# 12
# 10
# 13
# 10
# 2
# 10
# 15
# 14
# 10
# 14
# 13
# 13
# 13
# 11
# 8
# 9
# 4
# 11
# 14
# 15
# 2
# 3
# 2
# 14
# 8
# 9
# 15
# 8
# 6
# 5
# 7
# 6
# 3
# 5
# 14
# 13
# 11
# 1
# 4
# 14
# 8
# 1
# 11
# 9
# 15
# 5
# 13
# 11
# 12
# 8
# 2
# 7
# 3
# 11
# 9
# 1
# 1
# 8
# 10
# 11
# 3
# 7
# 2
# 5
# 1
# 3
# 7
# 7
# 1
# 4
# 5
# 1
# 2
# 10
# 4
# 10
# 8
# 11
# 5
# 4
# 1
# 6
# ...
