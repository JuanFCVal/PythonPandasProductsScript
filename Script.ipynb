# %%
#import dependencies
import pandas as pd
from pprint import pprint
#Read Kaggle Files in my DataFrame  
df1 = pd.read_csv('FashionClothing.csv', encoding = 'ISO-8859-1')
df2 = pd.read_csv('SummerProducts.csv', encoding = 'UTF-8')

# %%
df1 #Reading File 1
df1.columns
# Out:
# Index(['Product_URL', 'Brand', 'Description', 'Id_Product', 'URL_image',
#        'Category_by_gender', 'Discount Price (in Rs.)',
#        'Original Price (in Rs.)', 'Color'],
#       dtype='object')

# %%
df2['product_picture']
# Out:
# 0       https://contestimg.wish.com/api/webimage/5e9ae...
# 1       https://contestimg.wish.com/api/webimage/58940...
# 2       https://contestimg.wish.com/api/webimage/5ea10...
# 3       https://contestimg.wish.com/api/webimage/5cedf...
# 4       https://contestimg.wish.com/api/webimage/5ebf5...
#                               ...
# 1568    https://contestimg.wish.com/api/webimage/5d5fa...
# 1569    https://contestimg.wish.com/api/webimage/5eccd...
# 1570    https://contestimg.wish.com/api/webimage/5e74b...
# 1571    https://contestimg.wish.com/api/webimage/5eda0...
# 1572    https://contestimg.wish.com/api/webimage/5e857...
# Name: product_picture, Length: 1573, dtype: object

# %%
df2.columns
#title ,title_orig, price, retail_price, units_sold, rating, rating_count, product_url, product_picture, product_id, theme, tags, product_color, product_variation_size_id, shipping_option_price

#Agregar inventario manualmente, agregar porcentaje descuento, agregar marca, id negocios, fake_promo
# Out:
# Index(['title', 'title_orig', 'price', 'retail_price', 'currency_buyer',
#        'units_sold', 'uses_ad_boosts', 'rating', 'rating_count',
#        'rating_five_count', 'rating_four_count', 'rating_three_count',
#        'rating_two_count', 'rating_one_count', 'badges_count',
#        'badge_local_product', 'badge_product_quality', 'badge_fast_shipping',
#        'tags', 'product_color', 'product_variation_size_id',
#        'product_variation_inventory', 'shipping_option_name',
#        'shipping_option_price', 'shipping_is_express', 'countries_shipped_to',
#        'inventory_total', 'has_urgency_banner', 'urgency_text',
#        'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month'],
#       dtype='object')

# %%
df1 = df1[['Brand',]]  #Filter dataframe with relevant Columns
df1FinalVer = df1.iloc[:1500]
df1FinalVer
# Out:
#                      Brand
# 0                  netplay
# 1                  netplay
# 2     the-indian-garage-co
# 3                performax
# 4       john-players-jeans
# ...                    ...
# 1495          campus-sutra
# 1496                 levis
# 1497                adidas
# 1498            lee-cooper
# 1499               netplay
#
# [1500 rows x 1 columns]

# %%
#title ,title_orig, price, retail_price, units_sold, rating, rating_count, product_url, product_picture, product_id, theme, tags, product_color, product_variation_size_id, shipping_option_price
#Agregar inventario manualmente, agregar porcentaje descuento, agregar marca, id negocios, fake_promo
df2 = df2[['title', 'title_orig', "price", "retail_price", "units_sold", "rating", 'rating_count', "product_url", "product_picture", "product_id", "theme","tags", "product_color", "product_variation_size_id","shipping_option_price"]]  #Filter dataframe with relevant Columns
df2FinalVer = df2.iloc[:1500]                                                                   #Filter DataFrame Just to take 1500 Rows.
df2FinalVer
# Out:
#                                                   title  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1     SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2     2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3     Hot Summer Cool T-shirt pour les femmes Mode T...
# 4     Femmes Shorts d'été à lacets taille élastique ...
# ...                                                 ...
# 1495  Femmes d'été décontracté couleur unie col en V...
# 1496  Mode féminine grande taille Tops manches court...
# 1497  Mode Ocean Wave Bague Argent et Or Rose Bague ...
# 1498  Plus Size S-5XL Women Fashion Tube Top Dress O...
# 1499  Femmes été mode lacets pantalon court décontra...
#
#                                              title_orig  price  retail_price  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1      Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# ...

# %%
for col in df2FinalVer.columns:
    df1FinalVer[col] = df2FinalVer[col]
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18408\3288303009.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1FinalVer[col] = df2FinalVer[col]
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18408\3288303009.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1FinalVer[col] = df2FinalVer[col]
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18408\3288303009.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Out:
# 16

# %%
df1FinalVer['product_picture']
# Out:
# 0       https://contestimg.wish.com/api/webimage/5e9ae...
# 1       https://contestimg.wish.com/api/webimage/58940...
# 2       https://contestimg.wish.com/api/webimage/5ea10...
# 3       https://contestimg.wish.com/api/webimage/5cedf...
# 4       https://contestimg.wish.com/api/webimage/5ebf5...
#                               ...
# 1495    https://contestimg.wish.com/api/webimage/5d2d3...
# 1496    https://contestimg.wish.com/api/webimage/5cb9e...
# 1497    https://contestimg.wish.com/api/webimage/5aa35...
# 1498    https://contestimg.wish.com/api/webimage/5c887...
# 1499    https://contestimg.wish.com/api/webimage/5c662...
# Name: product_picture, Length: 1500, dtype: object

# %%
import random
import string
def get_random_string(length):
    # choose from all lowercase letter
    letters = string.ascii_lowercase
    result_str = ''.join(random.choice(letters) for i in range(length))
    return result_str

# %%
arrayBusinessIds = []
arrayBusinessIds = ['dumijjxgdkhk',
 'tiyqrehctiub',
 'thvcegjoprig',
 'pkrczvjwcwmo',
 'gjrwqigrslac',
 'xpfstgmwmpzh',
 'pehabikjnilf',
 'vktunkhdirsc',
 'sewehzdubsqk',
 'jkveiysoosoa',
 'kynbhlffmupr',
 'cwcofnbctuio',
 'wzxtmunjkiyv',
 'xpwowxmfgufw',
 'vedzlhcmcbiu',
 'wptzfozwceva',
 'vvwqhmphwcfu',
 'oxrvrhfioofw',
 'bwbivvjshioe',
 'bbhrwulprtjg']
# for x in range (0,20):
#     arrayBusinessIds.append(get_random_string(12))

# %%
#I generate an Array that are going to contain iDs because I need to add an idBusiness to Dataframe. So I select random numbers between 1-20 
import random              
idArray = []
for x in range(0, 1500):
    idArray.append(arrayBusinessIds[random.randint(0, 19)])
#Add the new column to Dataframe
df1FinalVer['idBusiness'] = idArray

# %%
#This is just to see how much coincidences are in each number.
counterDictionary = {}
for x in idArray:
    if x in counterDictionary:
        counterDictionary[x] = counterDictionary[x] + 1
    else:
         counterDictionary[x] = 1
counterDictionary
# Out:
# {'dumijjxgdkhk': 76,
#  'bbhrwulprtjg': 75,
#  'wptzfozwceva': 66,
#  'cwcofnbctuio': 71,
#  'pehabikjnilf': 58,
#  'oxrvrhfioofw': 96,
#  'gjrwqigrslac': 70,
#  'thvcegjoprig': 70,
#  'sewehzdubsqk': 98,
#  'tiyqrehctiub': 78,
#  'jkveiysoosoa': 75,
#  'xpwowxmfgufw': 79,
#  'vedzlhcmcbiu': 79,
#  'xpfstgmwmpzh': 66,
#  'pkrczvjwcwmo': 75,
#  'wzxtmunjkiyv': 89,
#  'vktunkhdirsc': 60,
#  'kynbhlffmupr': 71,
#  'bwbivvjshioe': 87,
#  'vvwqhmphwcfu': 61}

# %%
df1FinalVer['product_picture']
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18408\790500100.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1FinalVer['idBusiness'] = idArray
# 0       https://contestimg.wish.com/api/webimage/5e9ae...
# 1       https://contestimg.wish.com/api/webimage/58940...
# 2       https://contestimg.wish.com/api/webimage/5ea10...
# 3       https://contestimg.wish.com/api/webimage/5cedf...
# 4       https://contestimg.wish.com/api/webimage/5ebf5...
#                               ...
# 1495    https://contestimg.wish.com/api/webimage/5d2d3...
# 1496    https://contestimg.wish.com/api/webimage/5cb9e...
# 1497    https://contestimg.wish.com/api/webimage/5aa35...
# 1498    https://contestimg.wish.com/api/webimage/5c887...
# ...

# %%
arryConcatedData = []
for index, row in df1FinalVer.iterrows():
     concatedData = row['Brand'] + row['Category_by_gender']  + " " + row['title'] + " " + row['tags']  + " " + str(row['product_color'])  
     arryConcatedData.append(concatedData)
len(arryConcatedData)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
df1FinalVer['concatedData'] = arryConcatedData
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_20076\3679526903.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1FinalVer['concatedData'] = arryConcatedData

# %%
df1FinalVer.columns
# Out:
# Index(['Brand', 'title', 'title_orig', 'price', 'retail_price', 'units_sold',
#        'rating', 'rating_count', 'product_url', 'product_picture',
#        'product_id', 'theme', 'tags', 'product_color',
#        'product_variation_size_id', 'shipping_option_price', 'idBusiness'],
#       dtype='object')

# %%
import codecs
import json
data = json.dumps(df1FinalVer.values.tolist())

# data = df1FinalVer.to_json(orient='index') #T
# data
file = codecs.open("data.json", "w")
file.write(data)
file.close()

# data = df1FinalVer.to_json(orient='index') #Turn in to json data
# #open text file
# text_file = open("data.json", "w", "utf-8")
# #write string to file
# text_file.write(data)
# #close file
# text_file.close()
